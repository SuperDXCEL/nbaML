# %% [markdown]
# This notebook takes the hybrid approach as per **Hybrid Basketball Game Outcome Prediction Model by
# Integrating Data Mining Methods for the National
# Basketball Association**, using a dataframe with the last 11 seasons with team's averages, no rival averages present or league-wide ranks, the dataframe used when training a Random Forest, a Decision Tree and XGBoost on both regression and classification (points and win/loss) has, for each statistic, an individual lag of 1-4 and an overall lag of the last 4 games. The features have no normalization.

# %%
import pandas as pd
pd.options.display.max_columns = None

games = pd.read_csv('/kaggle/input/trulylastelevenseasons/games_from_last_eleven_seasons_with_averages (1).csv')
games.head()
# Out:
#    Unnamed: 0     Team_ID   Game_ID   GAME_DATE      MATCHUP WL   W   L  \
# 0           0  1610612737  21401217  2015-04-15    ATL @ CHI  L  60  22
# 1           1  1610612737  21401205  2015-04-13  ATL vs. NYK  L  60  21
# 2           2  1610612737  21401198  2015-04-12    ATL @ WAS  L  60  20
# 3           3  1610612737  21401176  2015-04-10  ATL vs. CHA  W  60  19
# 4           4  1610612737  21401163  2015-04-08    ATL @ BKN  W  59  19
#
#    W_PCT  MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  \
# 0  0.732  240   36   92   0.391     8    29    0.276    5    7   0.714    10
# 1  0.741  240   39   88   0.443    11    32    0.344   19   23   0.826    12
# 2  0.750  240   36   87   0.414     9    29    0.310   18   24   0.750     7
# 3  0.759  240   41   82   0.500    10    28    0.357   12   16   0.750     9
# 4  0.756  240   43   86   0.500    11    28    0.393   17   25   0.680    10
#
#    DREB  REB  AST  STL  BLK  TOV  PF  PTS   Season     AVG_MIN    AVG_FGM  \
# 0    32   42   15   10   10   15  19   85  2014-15  240.617284  38.086420
# 1    25   37   27   10    3    8  17  108  2014-15  240.625000  38.075000
# 2    31   38   24   10    2   11  22   99  2014-15  240.632911  38.101266
# 3    35   44   31   10    4   13  18  104  2014-15  240.641026  38.064103
# 4    30   40   35   11    4   11  18  114  2014-15  240.649351  38.000000
#
#      AVG_FGA  AVG_FG_PCT   AVG_FG3M   AVG_FG3A  AVG_FG3_PCT    AVG_FTM  \
# 0  81.567901    0.468123  10.000000  26.209877     0.381432  16.592593
# 1  81.487500    0.468438   9.987500  26.137500     0.381900  16.562500
# 2  81.417722    0.469127  10.000000  26.101266     0.382810  16.544304
# 3  81.410256    0.468731  10.000000  26.076923     0.383141  16.602564
# 4  81.350649    0.468325   9.987013  26.051948     0.383013  16.597403
#
#      AVG_FTA  AVG_FT_PCT  AVG_OREB   AVG_DREB    AVG_REB    AVG_AST   AVG_STL  \
# 0  21.333333    0.777284  8.703704  31.839506  40.543210  25.876543  9.061728
# 1  21.312500    0.776675  8.662500  31.925000  40.587500  25.862500  9.050000
# 2  21.278481    0.777013  8.683544  31.936709  40.620253  25.886076  9.037975
# 3  21.346154    0.777359  8.679487  31.897436  40.576923  25.820513  9.025641
# 4  21.298701    0.778623  8.662338  31.922078  40.584416  25.701299  9.000000
#
#     AVG_BLK    AVG_TOV     AVG_PF     AVG_PTS
# 0  4.567901  13.432099  17.753086  102.765432
# 1  4.587500  13.500000  17.762500  102.700000
# 2  4.620253  13.531646  17.708861  102.746835
# 3  4.628205  13.538462  17.705128  102.730769
# 4  4.636364  13.571429  17.701299  102.584416

# %%
# Let's calculate 2P%
def calc_2PCT(df):
    df['2PM'] = df['FGM'] - df['FG3M']
    df['2PA'] = df['FGA'] - df['FG3A']
    df['2P_PCT'] = df['2PM'] / df['2PA']

def matchup(matchup: str):
    if '@' in matchup:
        return matchup[6:]
    else:
        return matchup[7:]

calc_2PCT(games)
games['Team'] = games['MATCHUP'].astype(str).str[:3]
games['Rival'] = games['MATCHUP'].apply(matchup)
games['Home'] = games['MATCHUP'].apply(lambda x: True if 'vs' in x else False)
games.drop(columns=['MATCHUP', 'Unnamed: 0'], inplace=True)
games.head()
# Out:
#       Team_ID   Game_ID   GAME_DATE WL   W   L  W_PCT  MIN  FGM  FGA  FG_PCT  \
# 0  1610612737  21401217  2015-04-15  L  60  22  0.732  240   36   92   0.391
# 1  1610612737  21401205  2015-04-13  L  60  21  0.741  240   39   88   0.443
# 2  1610612737  21401198  2015-04-12  L  60  20  0.750  240   36   87   0.414
# 3  1610612737  21401176  2015-04-10  W  60  19  0.759  240   41   82   0.500
# 4  1610612737  21401163  2015-04-08  W  59  19  0.756  240   43   86   0.500
#
#    FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0     8    29    0.276    5    7   0.714    10    32   42   15   10   10   15
# 1    11    32    0.344   19   23   0.826    12    25   37   27   10    3    8
# 2     9    29    0.310   18   24   0.750     7    31   38   24   10    2   11
# 3    10    28    0.357   12   16   0.750     9    35   44   31   10    4   13
# 4    11    28    0.393   17   25   0.680    10    30   40   35   11    4   11
#
#    PF  PTS   Season     AVG_MIN    AVG_FGM    AVG_FGA  AVG_FG_PCT   AVG_FG3M  \
# 0  19   85  2014-15  240.617284  38.086420  81.567901    0.468123  10.000000
# 1  17  108  2014-15  240.625000  38.075000  81.487500    0.468438   9.987500
# 2  22   99  2014-15  240.632911  38.101266  81.417722    0.469127  10.000000
# 3  18  104  2014-15  240.641026  38.064103  81.410256    0.468731  10.000000
# 4  18  114  2014-15  240.649351  38.000000  81.350649    0.468325   9.987013
#
#     AVG_FG3A  AVG_FG3_PCT    AVG_FTM    AVG_FTA  AVG_FT_PCT  AVG_OREB  \
# 0  26.209877     0.381432  16.592593  21.333333    0.777284  8.703704
# 1  26.137500     0.381900  16.562500  21.312500    0.776675  8.662500
# 2  26.101266     0.382810  16.544304  21.278481    0.777013  8.683544
# 3  26.076923     0.383141  16.602564  21.346154    0.777359  8.679487
# 4  26.051948     0.383013  16.597403  21.298701    0.778623  8.662338
#
#     AVG_DREB    AVG_REB    AVG_AST   AVG_STL   AVG_BLK    AVG_TOV     AVG_PF  \
# 0  31.839506  40.543210  25.876543  9.061728  4.567901  13.432099  17.753086
# 1  31.925000  40.587500  25.862500  9.050000  4.587500  13.500000  17.762500
# 2  31.936709  40.620253  25.886076  9.037975  4.620253  13.531646  17.708861
# 3  31.897436  40.576923  25.820513  9.025641  4.628205  13.538462  17.705128
# 4  31.922078  40.584416  25.701299  9.000000  4.636364  13.571429  17.701299
#
#       AVG_PTS  2PM  2PA    2P_PCT Team Rival   Home
# 0  102.765432   28   63  0.444444  ATL   CHI  False
# 1  102.700000   28   56  0.500000  ATL   NYK   True
# 2  102.746835   27   58  0.465517  ATL   WAS  False
# 3  102.730769   31   54  0.574074  ATL   CHA   True
# 4  102.584416   32   58  0.551724  ATL   BKN  False

# %%
def lagged(df, stats):
    df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])
    df = df.sort_values(by=['Team_ID', 'GAME_DATE'])
    lags = 4
    for stat in stats:
        for lag in range(1, lags + 1):
            df[f"{stat}_lag{lag}"] = df.groupby('Team_ID')[stat].shift(lag)
    df = df.dropna()
    for stat in stats:
        df[f"lagged_{stat}"] = (df[f"{stat}_lag1"] + df[f"{stat}_lag2"] + df[f"{stat}_lag3"] + df[f"{stat}_lag4"]) / 4
    return df
games = lagged(games, ['FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FT_PCT', 'FTM', 'FTA', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', '2P_PCT'])
games.head()
# Out:
#        Team_ID   Game_ID  GAME_DATE WL  W  L  W_PCT  MIN  FGM  FGA  FG_PCT  \
# 77  1610612737  21400084 2014-11-08  W  2  3  0.400  240   33   81   0.407
# 76  1610612737  21400100 2014-11-10  W  3  3  0.500  240   27   71   0.380
# 75  1610612737  21400110 2014-11-12  W  4  3  0.571  240   39   76   0.513
# 74  1610612737  21400124 2014-11-14  W  5  3  0.625  240   42   75   0.560
# 73  1610612737  21400133 2014-11-15  L  5  4  0.556  240   40   90   0.444
#
#     FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  \
# 77     9    22    0.409   28   36   0.778    12    29   41   18   10    5
# 76    10    27    0.370   27   28   0.964     9    29   38   20    7    3
# 75     9    20    0.450   13   18   0.722    13    33   46   23    8    4
# 74    11    28    0.393   19   23   0.826     3    33   36   33   10    5
# 73     3    22    0.136   11   13   0.846    11    26   37   26    6    8
#
#     TOV  PF  PTS   Season     AVG_MIN    AVG_FGM    AVG_FGA  AVG_FG_PCT  \
# 77    8  17  103  2014-15  252.500000  39.000000  83.500000    0.470500
# 76   15  16   91  2014-15  250.000000  37.800000  83.000000    0.457800
# 75   18  12  100  2014-15  248.333333  36.000000  81.000000    0.444833
# 74   13  20  114  2014-15  247.142857  36.428571  80.285714    0.454571
# 73   18  12   94  2014-15  246.250000  37.125000  79.625000    0.467750
#
#      AVG_FG3M   AVG_FG3A  AVG_FG3_PCT    AVG_FTM    AVG_FTA  AVG_FT_PCT  \
# 77  10.250000  25.000000     0.413750  15.500000  21.750000    0.695750
# 76  10.000000  24.400000     0.412800  18.000000  24.600000    0.712200
# 75  10.000000  24.833333     0.405667  19.500000  25.166667    0.754167
# 74   9.857143  24.142857     0.412000  18.571429  24.142857    0.749571
# 73  10.000000  24.625000     0.409625  18.625000  24.000000    0.759125
#
#     AVG_OREB   AVG_DREB    AVG_REB    AVG_AST   AVG_STL   AVG_BLK    AVG_TOV  \
# 77  7.500000  31.000000  38.500000  26.500000  9.500000  5.500000  15.250000
# 76  8.400000  30.600000  39.000000  24.800000  9.600000  5.400000  13.800000
# 75  8.500000  30.333333  38.833333  24.000000  9.166667  5.000000  14.000000
# 74  9.142857  30.714286  39.857143  23.857143  9.000000  4.857143  14.571429
# 73  8.375000  31.000000  39.375000  25.000000  9.125000  4.875000  14.375000
#
#     AVG_PF     AVG_PTS  2PM  2PA    2P_PCT Team Rival   Home  FGM_lag1  \
# 77  25.500  103.750000   24   59  0.406780  ATL   NYK   True      43.0
# 76  23.800  103.600000   17   44  0.386364  ATL   NYK  False      33.0
# 75  22.500  101.500000   30   56  0.535714  ATL   UTA   True      27.0
# 74  21.000  101.285714   31   47  0.659574  ATL   MIA   True      39.0
# 73  20.875  102.875000   37   68  0.544118  ATL   CLE  False      42.0
#
#     FGM_lag2  FGM_lag3  FGM_lag4  FGA_lag1  FGA_lag2  FGA_lag3  FGA_lag4  \
# 77      38.0      35.0      40.0      93.0      92.0      69.0      80.0
# 76      43.0      38.0      35.0      81.0      93.0      92.0      69.0
# 75      33.0      43.0      38.0      71.0      81.0      93.0      92.0
# 74      27.0      33.0      43.0      76.0      71.0      81.0      93.0
# 73      39.0      27.0      33.0      75.0      76.0      71.0      81.0
#
#     FG_PCT_lag1  FG_PCT_lag2  FG_PCT_lag3  FG_PCT_lag4  FG3M_lag1  FG3M_lag2  \
# 77        0.462        0.413        0.507        0.500       13.0        8.0
# 76        0.407        0.462        0.413        0.507        9.0       13.0
# 75        0.380        0.407        0.462        0.413       10.0        9.0
# 74        0.513        0.380        0.407        0.462        9.0       10.0
# 73        0.560        0.513        0.380        0.407       11.0        9.0
#
#     FG3M_lag3  FG3M_lag4  FG3A_lag1  FG3A_lag2  FG3A_lag3  FG3A_lag4  \
# 77        7.0       13.0       33.0       25.0       20.0       22.0
# 76        8.0        7.0       22.0       33.0       25.0       20.0
# 75       13.0        8.0       27.0       22.0       33.0       25.0
# 74        9.0       13.0       20.0       27.0       22.0       33.0
# 73       10.0        9.0       28.0       20.0       27.0       22.0
#
#     FG3_PCT_lag1  FG3_PCT_lag2  FG3_PCT_lag3  FG3_PCT_lag4  FT_PCT_lag1  \
# 77         0.394         0.320         0.350         0.591        0.769
# 76         0.409         0.394         0.320         0.350        0.778
# 75         0.370         0.409         0.394         0.320        0.964
# 74         0.450         0.370         0.409         0.394        0.722
# 73         0.393         0.450         0.370         0.409        0.826
#
#     FT_PCT_lag2  FT_PCT_lag3  FT_PCT_lag4  FTM_lag1  FTM_lag2  FTM_lag3  \
# 77        0.727        0.758        0.529      20.0       8.0      25.0
# 76        0.769        0.727        0.758      28.0      20.0       8.0
# 75        0.778        0.769        0.727      27.0      28.0      20.0
# 74        0.964        0.778        0.769      13.0      27.0      28.0
# 73        0.722        0.964        0.778      19.0      13.0      27.0
#
#     FTM_lag4  FTA_lag1  FTA_lag2  FTA_lag3  FTA_lag4  OREB_lag1  OREB_lag2  \
# 77       9.0      26.0      11.0      33.0      17.0        7.0       10.0
# 76      25.0      36.0      26.0      11.0      33.0       12.0        7.0
# 75       8.0      28.0      36.0      26.0      11.0        9.0       12.0
# 74      20.0      18.0      28.0      36.0      26.0       13.0        9.0
# 73      28.0      23.0      18.0      28.0      36.0        3.0       13.0
#
#     OREB_lag3  OREB_lag4  DREB_lag1  DREB_lag2  DREB_lag3  DREB_lag4  \
# 77        3.0       10.0       31.0       27.0       34.0       32.0
# 76       10.0        3.0       29.0       31.0       27.0       34.0
# 75        7.0       10.0       29.0       29.0       31.0       27.0
# 74       12.0        7.0       33.0       29.0       29.0       31.0
# 73        9.0       12.0       33.0       33.0       29.0       29.0
#
#     REB_lag1  REB_lag2  REB_lag3  REB_lag4  AST_lag1  AST_lag2  AST_lag3  \
# 77      38.0      37.0      37.0      42.0      28.0      26.0      26.0
# 76      41.0      38.0      37.0      37.0      18.0      28.0      26.0
# 75      38.0      41.0      38.0      37.0      20.0      18.0      28.0
# 74      46.0      38.0      41.0      38.0      23.0      20.0      18.0
# 73      36.0      46.0      38.0      41.0      33.0      23.0      20.0
#
#     AST_lag4  STL_lag1  STL_lag2  STL_lag3  STL_lag4  BLK_lag1  BLK_lag2  \
# 77      26.0       8.0      14.0      10.0       6.0       3.0       5.0
# 76      26.0      10.0       8.0      14.0      10.0       5.0       3.0
# 75      26.0       7.0      10.0       8.0      14.0       3.0       5.0
# 74      28.0       8.0       7.0      10.0       8.0       4.0       3.0
# 73      18.0      10.0       8.0       7.0      10.0       5.0       4.0
#
#     BLK_lag3  BLK_lag4  TOV_lag1  TOV_lag2  TOV_lag3  TOV_lag4  PF_lag1  \
# 77       6.0       8.0      19.0      13.0      12.0      17.0     33.0
# 76       5.0       6.0       8.0      19.0      13.0      12.0     17.0
# 75       3.0       5.0      15.0       8.0      19.0      13.0     16.0
# 74       5.0       3.0      18.0      15.0       8.0      19.0     12.0
# 73       3.0       5.0      13.0      18.0      15.0       8.0     20.0
#
#     PF_lag2  PF_lag3  PF_lag4  2P_PCT_lag1  2P_PCT_lag2  2P_PCT_lag3  \
# 77     25.0     20.0     24.0     0.500000     0.447761     0.571429
# 76     33.0     25.0     20.0     0.406780     0.500000     0.447761
# 75     17.0     33.0     25.0     0.386364     0.406780     0.500000
# 74     16.0     17.0     33.0     0.535714     0.386364     0.406780
# 73     12.0     16.0     17.0     0.659574     0.535714     0.386364
#
#     2P_PCT_lag4  lagged_FGM  lagged_FGA  lagged_FG_PCT  lagged_FG3M  \
# 77     0.465517       39.00       83.50        0.47050        10.25
# 76     0.571429       37.25       83.75        0.44725         9.25
# 75     0.447761       35.25       84.25        0.41550        10.00
# 74     0.500000       35.50       80.25        0.44050        10.25
# 73     0.406780       35.25       75.75        0.46500         9.75
#
#     lagged_FG3A  lagged_FG3_PCT  lagged_FT_PCT  lagged_FTM  lagged_FTA  \
# 77        25.00         0.41375        0.69575       15.50       21.75
# 76        25.00         0.36825        0.75800       20.25       26.50
# 75        26.75         0.37325        0.80950       20.75       25.25
# 74        25.50         0.40575        0.80825       22.00       27.00
# 73        24.25         0.40550        0.82250       21.75       26.25
#
#     lagged_OREB  lagged_DREB  lagged_REB  lagged_AST  lagged_STL  lagged_BLK  \
# 77         7.50        31.00       38.50       26.50        9.50        5.50
# 76         8.00        30.25       38.25       24.50       10.50        4.75
# 75         9.50        29.00       38.50       23.00        9.75        4.00
# 74        10.25        30.50       40.75       22.25        8.25        3.75
# 73         9.25        31.00       40.25       23.50        8.75        4.25
#
#     lagged_TOV  lagged_PF  lagged_2P_PCT
# 77       15.25      25.50       0.496177
# 76       13.00      23.75       0.481492
# 75       13.75      22.75       0.435226
# 74       15.00      19.50       0.457214
# 73       13.50      16.25       0.497108

# %%
games['Year'] = games['GAME_DATE'].dt.year
games['Month'] = games['GAME_DATE'].dt.month
games['Day'] = games['GAME_DATE'].dt.day
games.head()
# Out:
# <ipython-input-4-8df11e03d5eb>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   games['Year'] = games['GAME_DATE'].dt.year
# <ipython-input-4-8df11e03d5eb>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   games['Month'] = games['GAME_DATE'].dt.month
# <ipython-input-4-8df11e03d5eb>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   games['Day'] = games['GAME_DATE'].dt.day
#        Team_ID   Game_ID  GAME_DATE WL  W  L  W_PCT  MIN  FGM  FGA  FG_PCT  \
# 77  1610612737  21400084 2014-11-08  W  2  3  0.400  240   33   81   0.407
# 76  1610612737  21400100 2014-11-10  W  3  3  0.500  240   27   71   0.380
# 75  1610612737  21400110 2014-11-12  W  4  3  0.571  240   39   76   0.513
# 74  1610612737  21400124 2014-11-14  W  5  3  0.625  240   42   75   0.560
# 73  1610612737  21400133 2014-11-15  L  5  4  0.556  240   40   90   0.444
#
#     FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  \
# 77     9    22    0.409   28   36   0.778    12    29   41   18   10    5
# 76    10    27    0.370   27   28   0.964     9    29   38   20    7    3
# 75     9    20    0.450   13   18   0.722    13    33   46   23    8    4
# 74    11    28    0.393   19   23   0.826     3    33   36   33   10    5
# 73     3    22    0.136   11   13   0.846    11    26   37   26    6    8
#
#     TOV  PF  PTS   Season     AVG_MIN    AVG_FGM    AVG_FGA  AVG_FG_PCT  \
# 77    8  17  103  2014-15  252.500000  39.000000  83.500000    0.470500
# 76   15  16   91  2014-15  250.000000  37.800000  83.000000    0.457800
# 75   18  12  100  2014-15  248.333333  36.000000  81.000000    0.444833
# 74   13  20  114  2014-15  247.142857  36.428571  80.285714    0.454571
# 73   18  12   94  2014-15  246.250000  37.125000  79.625000    0.467750
#
#      AVG_FG3M   AVG_FG3A  AVG_FG3_PCT    AVG_FTM    AVG_FTA  AVG_FT_PCT  \
# 77  10.250000  25.000000     0.413750  15.500000  21.750000    0.695750
# 76  10.000000  24.400000     0.412800  18.000000  24.600000    0.712200
# 75  10.000000  24.833333     0.405667  19.500000  25.166667    0.754167
# 74   9.857143  24.142857     0.412000  18.571429  24.142857    0.749571
# 73  10.000000  24.625000     0.409625  18.625000  24.000000    0.759125
#
#     AVG_OREB   AVG_DREB    AVG_REB    AVG_AST   AVG_STL   AVG_BLK    AVG_TOV  \
# 77  7.500000  31.000000  38.500000  26.500000  9.500000  5.500000  15.250000
# 76  8.400000  30.600000  39.000000  24.800000  9.600000  5.400000  13.800000
# 75  8.500000  30.333333  38.833333  24.000000  9.166667  5.000000  14.000000
# 74  9.142857  30.714286  39.857143  23.857143  9.000000  4.857143  14.571429
# 73  8.375000  31.000000  39.375000  25.000000  9.125000  4.875000  14.375000
#
#     AVG_PF     AVG_PTS  2PM  2PA    2P_PCT Team Rival   Home  FGM_lag1  \
# 77  25.500  103.750000   24   59  0.406780  ATL   NYK   True      43.0
# 76  23.800  103.600000   17   44  0.386364  ATL   NYK  False      33.0
# 75  22.500  101.500000   30   56  0.535714  ATL   UTA   True      27.0
# 74  21.000  101.285714   31   47  0.659574  ATL   MIA   True      39.0
# 73  20.875  102.875000   37   68  0.544118  ATL   CLE  False      42.0
#
#     FGM_lag2  FGM_lag3  FGM_lag4  FGA_lag1  FGA_lag2  FGA_lag3  FGA_lag4  \
# 77      38.0      35.0      40.0      93.0      92.0      69.0      80.0
# 76      43.0      38.0      35.0      81.0      93.0      92.0      69.0
# 75      33.0      43.0      38.0      71.0      81.0      93.0      92.0
# 74      27.0      33.0      43.0      76.0      71.0      81.0      93.0
# 73      39.0      27.0      33.0      75.0      76.0      71.0      81.0
#
#     FG_PCT_lag1  FG_PCT_lag2  FG_PCT_lag3  FG_PCT_lag4  FG3M_lag1  FG3M_lag2  \
# 77        0.462        0.413        0.507        0.500       13.0        8.0
# 76        0.407        0.462        0.413        0.507        9.0       13.0
# 75        0.380        0.407        0.462        0.413       10.0        9.0
# 74        0.513        0.380        0.407        0.462        9.0       10.0
# 73        0.560        0.513        0.380        0.407       11.0        9.0
#
#     FG3M_lag3  FG3M_lag4  FG3A_lag1  FG3A_lag2  FG3A_lag3  FG3A_lag4  \
# 77        7.0       13.0       33.0       25.0       20.0       22.0
# 76        8.0        7.0       22.0       33.0       25.0       20.0
# 75       13.0        8.0       27.0       22.0       33.0       25.0
# 74        9.0       13.0       20.0       27.0       22.0       33.0
# 73       10.0        9.0       28.0       20.0       27.0       22.0
#
#     FG3_PCT_lag1  FG3_PCT_lag2  FG3_PCT_lag3  FG3_PCT_lag4  FT_PCT_lag1  \
# 77         0.394         0.320         0.350         0.591        0.769
# 76         0.409         0.394         0.320         0.350        0.778
# 75         0.370         0.409         0.394         0.320        0.964
# 74         0.450         0.370         0.409         0.394        0.722
# 73         0.393         0.450         0.370         0.409        0.826
#
#     FT_PCT_lag2  FT_PCT_lag3  FT_PCT_lag4  FTM_lag1  FTM_lag2  FTM_lag3  \
# 77        0.727        0.758        0.529      20.0       8.0      25.0
# 76        0.769        0.727        0.758      28.0      20.0       8.0
# 75        0.778        0.769        0.727      27.0      28.0      20.0
# 74        0.964        0.778        0.769      13.0      27.0      28.0
# 73        0.722        0.964        0.778      19.0      13.0      27.0
#
#     FTM_lag4  FTA_lag1  FTA_lag2  FTA_lag3  FTA_lag4  OREB_lag1  OREB_lag2  \
# 77       9.0      26.0      11.0      33.0      17.0        7.0       10.0
# 76      25.0      36.0      26.0      11.0      33.0       12.0        7.0
# 75       8.0      28.0      36.0      26.0      11.0        9.0       12.0
# 74      20.0      18.0      28.0      36.0      26.0       13.0        9.0
# 73      28.0      23.0      18.0      28.0      36.0        3.0       13.0
#
#     OREB_lag3  OREB_lag4  DREB_lag1  DREB_lag2  DREB_lag3  DREB_lag4  \
# 77        3.0       10.0       31.0       27.0       34.0       32.0
# 76       10.0        3.0       29.0       31.0       27.0       34.0
# 75        7.0       10.0       29.0       29.0       31.0       27.0
# 74       12.0        7.0       33.0       29.0       29.0       31.0
# 73        9.0       12.0       33.0       33.0       29.0       29.0
#
#     REB_lag1  REB_lag2  REB_lag3  REB_lag4  AST_lag1  AST_lag2  AST_lag3  \
# 77      38.0      37.0      37.0      42.0      28.0      26.0      26.0
# 76      41.0      38.0      37.0      37.0      18.0      28.0      26.0
# 75      38.0      41.0      38.0      37.0      20.0      18.0      28.0
# 74      46.0      38.0      41.0      38.0      23.0      20.0      18.0
# 73      36.0      46.0      38.0      41.0      33.0      23.0      20.0
#
#     AST_lag4  STL_lag1  STL_lag2  STL_lag3  STL_lag4  BLK_lag1  BLK_lag2  \
# 77      26.0       8.0      14.0      10.0       6.0       3.0       5.0
# 76      26.0      10.0       8.0      14.0      10.0       5.0       3.0
# 75      26.0       7.0      10.0       8.0      14.0       3.0       5.0
# 74      28.0       8.0       7.0      10.0       8.0       4.0       3.0
# 73      18.0      10.0       8.0       7.0      10.0       5.0       4.0
#
#     BLK_lag3  BLK_lag4  TOV_lag1  TOV_lag2  TOV_lag3  TOV_lag4  PF_lag1  \
# 77       6.0       8.0      19.0      13.0      12.0      17.0     33.0
# 76       5.0       6.0       8.0      19.0      13.0      12.0     17.0
# 75       3.0       5.0      15.0       8.0      19.0      13.0     16.0
# 74       5.0       3.0      18.0      15.0       8.0      19.0     12.0
# 73       3.0       5.0      13.0      18.0      15.0       8.0     20.0
#
#     PF_lag2  PF_lag3  PF_lag4  2P_PCT_lag1  2P_PCT_lag2  2P_PCT_lag3  \
# 77     25.0     20.0     24.0     0.500000     0.447761     0.571429
# 76     33.0     25.0     20.0     0.406780     0.500000     0.447761
# 75     17.0     33.0     25.0     0.386364     0.406780     0.500000
# 74     16.0     17.0     33.0     0.535714     0.386364     0.406780
# 73     12.0     16.0     17.0     0.659574     0.535714     0.386364
#
#     2P_PCT_lag4  lagged_FGM  lagged_FGA  lagged_FG_PCT  lagged_FG3M  \
# 77     0.465517       39.00       83.50        0.47050        10.25
# 76     0.571429       37.25       83.75        0.44725         9.25
# 75     0.447761       35.25       84.25        0.41550        10.00
# 74     0.500000       35.50       80.25        0.44050        10.25
# 73     0.406780       35.25       75.75        0.46500         9.75
#
#     lagged_FG3A  lagged_FG3_PCT  lagged_FT_PCT  lagged_FTM  lagged_FTA  \
# 77        25.00         0.41375        0.69575       15.50       21.75
# 76        25.00         0.36825        0.75800       20.25       26.50
# 75        26.75         0.37325        0.80950       20.75       25.25
# 74        25.50         0.40575        0.80825       22.00       27.00
# 73        24.25         0.40550        0.82250       21.75       26.25
#
#     lagged_OREB  lagged_DREB  lagged_REB  lagged_AST  lagged_STL  lagged_BLK  \
# 77         7.50        31.00       38.50       26.50        9.50        5.50
# 76         8.00        30.25       38.25       24.50       10.50        4.75
# 75         9.50        29.00       38.50       23.00        9.75        4.00
# 74        10.25        30.50       40.75       22.25        8.25        3.75
# 73         9.25        31.00       40.25       23.50        8.75        4.25
#
#     lagged_TOV  lagged_PF  lagged_2P_PCT  Year  Month  Day
# 77       15.25      25.50       0.496177  2014     11    8
# 76       13.00      23.75       0.481492  2014     11   10
# 75       13.75      22.75       0.435226  2014     11   12
# 74       15.00      19.50       0.457214  2014     11   14
# 73       13.50      16.25       0.497108  2014     11   15

# %% [markdown]
# **MIN-MAX NORMALIZATION**

# %%
# games.drop(['Team_ID', 'GAME_DATE'], inplace=True, axis=1)
# vec = games.columns
# vec = vec.to_list()
# vec.remove('PTS')
# for item in vec:
#     big, small = games[item].max(), games[item].min()
#     games[item] = (games[item] - small) / (big - small)

# %%
df = games.drop(columns=[
    'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 
    'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 
    'STL', 'BLK', 'TOV', 'PF', 'Season', 'GAME_DATE', 'Team_ID', 'Game_ID',
])
df.head()
# Out:
#    WL  PTS     AVG_MIN    AVG_FGM    AVG_FGA  AVG_FG_PCT   AVG_FG3M  \
# 77  W  103  252.500000  39.000000  83.500000    0.470500  10.250000
# 76  W   91  250.000000  37.800000  83.000000    0.457800  10.000000
# 75  W  100  248.333333  36.000000  81.000000    0.444833  10.000000
# 74  W  114  247.142857  36.428571  80.285714    0.454571   9.857143
# 73  L   94  246.250000  37.125000  79.625000    0.467750  10.000000
#
#      AVG_FG3A  AVG_FG3_PCT    AVG_FTM    AVG_FTA  AVG_FT_PCT  AVG_OREB  \
# 77  25.000000     0.413750  15.500000  21.750000    0.695750  7.500000
# 76  24.400000     0.412800  18.000000  24.600000    0.712200  8.400000
# 75  24.833333     0.405667  19.500000  25.166667    0.754167  8.500000
# 74  24.142857     0.412000  18.571429  24.142857    0.749571  9.142857
# 73  24.625000     0.409625  18.625000  24.000000    0.759125  8.375000
#
#      AVG_DREB    AVG_REB    AVG_AST   AVG_STL   AVG_BLK    AVG_TOV  AVG_PF  \
# 77  31.000000  38.500000  26.500000  9.500000  5.500000  15.250000  25.500
# 76  30.600000  39.000000  24.800000  9.600000  5.400000  13.800000  23.800
# 75  30.333333  38.833333  24.000000  9.166667  5.000000  14.000000  22.500
# 74  30.714286  39.857143  23.857143  9.000000  4.857143  14.571429  21.000
# 73  31.000000  39.375000  25.000000  9.125000  4.875000  14.375000  20.875
#
#        AVG_PTS  2PM  2PA    2P_PCT Team Rival   Home  FGM_lag1  FGM_lag2  \
# 77  103.750000   24   59  0.406780  ATL   NYK   True      43.0      38.0
# 76  103.600000   17   44  0.386364  ATL   NYK  False      33.0      43.0
# 75  101.500000   30   56  0.535714  ATL   UTA   True      27.0      33.0
# 74  101.285714   31   47  0.659574  ATL   MIA   True      39.0      27.0
# 73  102.875000   37   68  0.544118  ATL   CLE  False      42.0      39.0
#
#     FGM_lag3  FGM_lag4  FGA_lag1  FGA_lag2  FGA_lag3  FGA_lag4  FG_PCT_lag1  \
# 77      35.0      40.0      93.0      92.0      69.0      80.0        0.462
# 76      38.0      35.0      81.0      93.0      92.0      69.0        0.407
# 75      43.0      38.0      71.0      81.0      93.0      92.0        0.380
# 74      33.0      43.0      76.0      71.0      81.0      93.0        0.513
# 73      27.0      33.0      75.0      76.0      71.0      81.0        0.560
#
#     FG_PCT_lag2  FG_PCT_lag3  FG_PCT_lag4  FG3M_lag1  FG3M_lag2  FG3M_lag3  \
# 77        0.413        0.507        0.500       13.0        8.0        7.0
# 76        0.462        0.413        0.507        9.0       13.0        8.0
# 75        0.407        0.462        0.413       10.0        9.0       13.0
# 74        0.380        0.407        0.462        9.0       10.0        9.0
# 73        0.513        0.380        0.407       11.0        9.0       10.0
#
#     FG3M_lag4  FG3A_lag1  FG3A_lag2  FG3A_lag3  FG3A_lag4  FG3_PCT_lag1  \
# 77       13.0       33.0       25.0       20.0       22.0         0.394
# 76        7.0       22.0       33.0       25.0       20.0         0.409
# 75        8.0       27.0       22.0       33.0       25.0         0.370
# 74       13.0       20.0       27.0       22.0       33.0         0.450
# 73        9.0       28.0       20.0       27.0       22.0         0.393
#
#     FG3_PCT_lag2  FG3_PCT_lag3  FG3_PCT_lag4  FT_PCT_lag1  FT_PCT_lag2  \
# 77         0.320         0.350         0.591        0.769        0.727
# 76         0.394         0.320         0.350        0.778        0.769
# 75         0.409         0.394         0.320        0.964        0.778
# 74         0.370         0.409         0.394        0.722        0.964
# 73         0.450         0.370         0.409        0.826        0.722
#
#     FT_PCT_lag3  FT_PCT_lag4  FTM_lag1  FTM_lag2  FTM_lag3  FTM_lag4  \
# 77        0.758        0.529      20.0       8.0      25.0       9.0
# 76        0.727        0.758      28.0      20.0       8.0      25.0
# 75        0.769        0.727      27.0      28.0      20.0       8.0
# 74        0.778        0.769      13.0      27.0      28.0      20.0
# 73        0.964        0.778      19.0      13.0      27.0      28.0
#
#     FTA_lag1  FTA_lag2  FTA_lag3  FTA_lag4  OREB_lag1  OREB_lag2  OREB_lag3  \
# 77      26.0      11.0      33.0      17.0        7.0       10.0        3.0
# 76      36.0      26.0      11.0      33.0       12.0        7.0       10.0
# 75      28.0      36.0      26.0      11.0        9.0       12.0        7.0
# 74      18.0      28.0      36.0      26.0       13.0        9.0       12.0
# 73      23.0      18.0      28.0      36.0        3.0       13.0        9.0
#
#     OREB_lag4  DREB_lag1  DREB_lag2  DREB_lag3  DREB_lag4  REB_lag1  REB_lag2  \
# 77       10.0       31.0       27.0       34.0       32.0      38.0      37.0
# 76        3.0       29.0       31.0       27.0       34.0      41.0      38.0
# 75       10.0       29.0       29.0       31.0       27.0      38.0      41.0
# 74        7.0       33.0       29.0       29.0       31.0      46.0      38.0
# 73       12.0       33.0       33.0       29.0       29.0      36.0      46.0
#
#     REB_lag3  REB_lag4  AST_lag1  AST_lag2  AST_lag3  AST_lag4  STL_lag1  \
# 77      37.0      42.0      28.0      26.0      26.0      26.0       8.0
# 76      37.0      37.0      18.0      28.0      26.0      26.0      10.0
# 75      38.0      37.0      20.0      18.0      28.0      26.0       7.0
# 74      41.0      38.0      23.0      20.0      18.0      28.0       8.0
# 73      38.0      41.0      33.0      23.0      20.0      18.0      10.0
#
#     STL_lag2  STL_lag3  STL_lag4  BLK_lag1  BLK_lag2  BLK_lag3  BLK_lag4  \
# 77      14.0      10.0       6.0       3.0       5.0       6.0       8.0
# 76       8.0      14.0      10.0       5.0       3.0       5.0       6.0
# 75      10.0       8.0      14.0       3.0       5.0       3.0       5.0
# 74       7.0      10.0       8.0       4.0       3.0       5.0       3.0
# 73       8.0       7.0      10.0       5.0       4.0       3.0       5.0
#
#     TOV_lag1  TOV_lag2  TOV_lag3  TOV_lag4  PF_lag1  PF_lag2  PF_lag3  \
# 77      19.0      13.0      12.0      17.0     33.0     25.0     20.0
# 76       8.0      19.0      13.0      12.0     17.0     33.0     25.0
# 75      15.0       8.0      19.0      13.0     16.0     17.0     33.0
# 74      18.0      15.0       8.0      19.0     12.0     16.0     17.0
# 73      13.0      18.0      15.0       8.0     20.0     12.0     16.0
#
#     PF_lag4  2P_PCT_lag1  2P_PCT_lag2  2P_PCT_lag3  2P_PCT_lag4  lagged_FGM  \
# 77     24.0     0.500000     0.447761     0.571429     0.465517       39.00
# 76     20.0     0.406780     0.500000     0.447761     0.571429       37.25
# 75     25.0     0.386364     0.406780     0.500000     0.447761       35.25
# 74     33.0     0.535714     0.386364     0.406780     0.500000       35.50
# 73     17.0     0.659574     0.535714     0.386364     0.406780       35.25
#
#     lagged_FGA  lagged_FG_PCT  lagged_FG3M  lagged_FG3A  lagged_FG3_PCT  \
# 77       83.50        0.47050        10.25        25.00         0.41375
# 76       83.75        0.44725         9.25        25.00         0.36825
# 75       84.25        0.41550        10.00        26.75         0.37325
# 74       80.25        0.44050        10.25        25.50         0.40575
# 73       75.75        0.46500         9.75        24.25         0.40550
#
#     lagged_FT_PCT  lagged_FTM  lagged_FTA  lagged_OREB  lagged_DREB  \
# 77        0.69575       15.50       21.75         7.50        31.00
# 76        0.75800       20.25       26.50         8.00        30.25
# 75        0.80950       20.75       25.25         9.50        29.00
# 74        0.80825       22.00       27.00        10.25        30.50
# 73        0.82250       21.75       26.25         9.25        31.00
#
#     lagged_REB  lagged_AST  lagged_STL  lagged_BLK  lagged_TOV  lagged_PF  \
# 77       38.50       26.50        9.50        5.50       15.25      25.50
# 76       38.25       24.50       10.50        4.75       13.00      23.75
# 75       38.50       23.00        9.75        4.00       13.75      22.75
# 74       40.75       22.25        8.25        3.75       15.00      19.50
# 73       40.25       23.50        8.75        4.25       13.50      16.25
#
#     lagged_2P_PCT  Year  Month  Day
# 77       0.496177  2014     11    8
# 76       0.481492  2014     11   10
# 75       0.435226  2014     11   12
# 74       0.457214  2014     11   14
# 73       0.497108  2014     11   15

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()
df['Month_Sin'] = np.sin(2 * np.pi * games['Month'] / 12)
df['Month_Cos'] = np.cos(2 * np.pi * games['Month'] / 12)
df['Day_Sin'] = np.sin(2 * np.pi * games['Day'] / 31)
df['Day_Cos'] = np.cos(2 * np.pi * games['Day'] / 31)
df['Team'] = LE.fit_transform(games['Team'])
df['Rival'] = LE.fit_transform(games['Rival'])
df['WL'] = LE.fit_transform(games['WL'])
df.drop(['Month', 'Day'], axis = 1, inplace=True)
df.head()
# Out:
# <ipython-input-7-d69286fe565b>:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Month_Sin'] = np.sin(2 * np.pi * games['Month'] / 12)
# <ipython-input-7-d69286fe565b>:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Month_Cos'] = np.cos(2 * np.pi * games['Month'] / 12)
# <ipython-input-7-d69286fe565b>:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Day_Sin'] = np.sin(2 * np.pi * games['Day'] / 31)
# <ipython-input-7-d69286fe565b>:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Day_Cos'] = np.cos(2 * np.pi * games['Day'] / 31)
#     WL  PTS     AVG_MIN    AVG_FGM    AVG_FGA  AVG_FG_PCT   AVG_FG3M  \
# 77   1  103  252.500000  39.000000  83.500000    0.470500  10.250000
# 76   1   91  250.000000  37.800000  83.000000    0.457800  10.000000
# 75   1  100  248.333333  36.000000  81.000000    0.444833  10.000000
# 74   1  114  247.142857  36.428571  80.285714    0.454571   9.857143
# 73   0   94  246.250000  37.125000  79.625000    0.467750  10.000000
#
#      AVG_FG3A  AVG_FG3_PCT    AVG_FTM    AVG_FTA  AVG_FT_PCT  AVG_OREB  \
# 77  25.000000     0.413750  15.500000  21.750000    0.695750  7.500000
# 76  24.400000     0.412800  18.000000  24.600000    0.712200  8.400000
# 75  24.833333     0.405667  19.500000  25.166667    0.754167  8.500000
# 74  24.142857     0.412000  18.571429  24.142857    0.749571  9.142857
# 73  24.625000     0.409625  18.625000  24.000000    0.759125  8.375000
#
#      AVG_DREB    AVG_REB    AVG_AST   AVG_STL   AVG_BLK    AVG_TOV  AVG_PF  \
# 77  31.000000  38.500000  26.500000  9.500000  5.500000  15.250000  25.500
# 76  30.600000  39.000000  24.800000  9.600000  5.400000  13.800000  23.800
# 75  30.333333  38.833333  24.000000  9.166667  5.000000  14.000000  22.500
# 74  30.714286  39.857143  23.857143  9.000000  4.857143  14.571429  21.000
# 73  31.000000  39.375000  25.000000  9.125000  4.875000  14.375000  20.875
#
#        AVG_PTS  2PM  2PA    2P_PCT  Team  Rival   Home  FGM_lag1  FGM_lag2  \
# 77  103.750000   24   59  0.406780     0     19   True      43.0      38.0
# 76  103.600000   17   44  0.386364     0     49  False      33.0      43.0
# 75  101.500000   30   56  0.535714     0     28   True      27.0      33.0
# 74  101.285714   31   47  0.659574     0     15   True      39.0      27.0
# 73  102.875000   37   68  0.544118     0     35  False      42.0      39.0
#
#     FGM_lag3  FGM_lag4  FGA_lag1  FGA_lag2  FGA_lag3  FGA_lag4  FG_PCT_lag1  \
# 77      35.0      40.0      93.0      92.0      69.0      80.0        0.462
# 76      38.0      35.0      81.0      93.0      92.0      69.0        0.407
# 75      43.0      38.0      71.0      81.0      93.0      92.0        0.380
# 74      33.0      43.0      76.0      71.0      81.0      93.0        0.513
# 73      27.0      33.0      75.0      76.0      71.0      81.0        0.560
#
#     FG_PCT_lag2  FG_PCT_lag3  FG_PCT_lag4  FG3M_lag1  FG3M_lag2  FG3M_lag3  \
# 77        0.413        0.507        0.500       13.0        8.0        7.0
# 76        0.462        0.413        0.507        9.0       13.0        8.0
# 75        0.407        0.462        0.413       10.0        9.0       13.0
# 74        0.380        0.407        0.462        9.0       10.0        9.0
# 73        0.513        0.380        0.407       11.0        9.0       10.0
#
#     FG3M_lag4  FG3A_lag1  FG3A_lag2  FG3A_lag3  FG3A_lag4  FG3_PCT_lag1  \
# 77       13.0       33.0       25.0       20.0       22.0         0.394
# 76        7.0       22.0       33.0       25.0       20.0         0.409
# 75        8.0       27.0       22.0       33.0       25.0         0.370
# 74       13.0       20.0       27.0       22.0       33.0         0.450
# 73        9.0       28.0       20.0       27.0       22.0         0.393
#
#     FG3_PCT_lag2  FG3_PCT_lag3  FG3_PCT_lag4  FT_PCT_lag1  FT_PCT_lag2  \
# 77         0.320         0.350         0.591        0.769        0.727
# 76         0.394         0.320         0.350        0.778        0.769
# 75         0.409         0.394         0.320        0.964        0.778
# 74         0.370         0.409         0.394        0.722        0.964
# 73         0.450         0.370         0.409        0.826        0.722
#
#     FT_PCT_lag3  FT_PCT_lag4  FTM_lag1  FTM_lag2  FTM_lag3  FTM_lag4  \
# 77        0.758        0.529      20.0       8.0      25.0       9.0
# 76        0.727        0.758      28.0      20.0       8.0      25.0
# 75        0.769        0.727      27.0      28.0      20.0       8.0
# 74        0.778        0.769      13.0      27.0      28.0      20.0
# 73        0.964        0.778      19.0      13.0      27.0      28.0
#
#     FTA_lag1  FTA_lag2  FTA_lag3  FTA_lag4  OREB_lag1  OREB_lag2  OREB_lag3  \
# 77      26.0      11.0      33.0      17.0        7.0       10.0        3.0
# 76      36.0      26.0      11.0      33.0       12.0        7.0       10.0
# 75      28.0      36.0      26.0      11.0        9.0       12.0        7.0
# 74      18.0      28.0      36.0      26.0       13.0        9.0       12.0
# 73      23.0      18.0      28.0      36.0        3.0       13.0        9.0
#
#     OREB_lag4  DREB_lag1  DREB_lag2  DREB_lag3  DREB_lag4  REB_lag1  REB_lag2  \
# 77       10.0       31.0       27.0       34.0       32.0      38.0      37.0
# 76        3.0       29.0       31.0       27.0       34.0      41.0      38.0
# 75       10.0       29.0       29.0       31.0       27.0      38.0      41.0
# 74        7.0       33.0       29.0       29.0       31.0      46.0      38.0
# 73       12.0       33.0       33.0       29.0       29.0      36.0      46.0
#
#     REB_lag3  REB_lag4  AST_lag1  AST_lag2  AST_lag3  AST_lag4  STL_lag1  \
# 77      37.0      42.0      28.0      26.0      26.0      26.0       8.0
# 76      37.0      37.0      18.0      28.0      26.0      26.0      10.0
# 75      38.0      37.0      20.0      18.0      28.0      26.0       7.0
# 74      41.0      38.0      23.0      20.0      18.0      28.0       8.0
# 73      38.0      41.0      33.0      23.0      20.0      18.0      10.0
#
#     STL_lag2  STL_lag3  STL_lag4  BLK_lag1  BLK_lag2  BLK_lag3  BLK_lag4  \
# 77      14.0      10.0       6.0       3.0       5.0       6.0       8.0
# 76       8.0      14.0      10.0       5.0       3.0       5.0       6.0
# 75      10.0       8.0      14.0       3.0       5.0       3.0       5.0
# 74       7.0      10.0       8.0       4.0       3.0       5.0       3.0
# 73       8.0       7.0      10.0       5.0       4.0       3.0       5.0
#
#     TOV_lag1  TOV_lag2  TOV_lag3  TOV_lag4  PF_lag1  PF_lag2  PF_lag3  \
# 77      19.0      13.0      12.0      17.0     33.0     25.0     20.0
# 76       8.0      19.0      13.0      12.0     17.0     33.0     25.0
# 75      15.0       8.0      19.0      13.0     16.0     17.0     33.0
# 74      18.0      15.0       8.0      19.0     12.0     16.0     17.0
# 73      13.0      18.0      15.0       8.0     20.0     12.0     16.0
#
#     PF_lag4  2P_PCT_lag1  2P_PCT_lag2  2P_PCT_lag3  2P_PCT_lag4  lagged_FGM  \
# 77     24.0     0.500000     0.447761     0.571429     0.465517       39.00
# 76     20.0     0.406780     0.500000     0.447761     0.571429       37.25
# 75     25.0     0.386364     0.406780     0.500000     0.447761       35.25
# 74     33.0     0.535714     0.386364     0.406780     0.500000       35.50
# 73     17.0     0.659574     0.535714     0.386364     0.406780       35.25
#
#     lagged_FGA  lagged_FG_PCT  lagged_FG3M  lagged_FG3A  lagged_FG3_PCT  \
# 77       83.50        0.47050        10.25        25.00         0.41375
# 76       83.75        0.44725         9.25        25.00         0.36825
# 75       84.25        0.41550        10.00        26.75         0.37325
# 74       80.25        0.44050        10.25        25.50         0.40575
# 73       75.75        0.46500         9.75        24.25         0.40550
#
#     lagged_FT_PCT  lagged_FTM  lagged_FTA  lagged_OREB  lagged_DREB  \
# 77        0.69575       15.50       21.75         7.50        31.00
# 76        0.75800       20.25       26.50         8.00        30.25
# 75        0.80950       20.75       25.25         9.50        29.00
# 74        0.80825       22.00       27.00        10.25        30.50
# 73        0.82250       21.75       26.25         9.25        31.00
#
#     lagged_REB  lagged_AST  lagged_STL  lagged_BLK  lagged_TOV  lagged_PF  \
# 77       38.50       26.50        9.50        5.50       15.25      25.50
# 76       38.25       24.50       10.50        4.75       13.00      23.75
# 75       38.50       23.00        9.75        4.00       13.75      22.75
# 74       40.75       22.25        8.25        3.75       15.00      19.50
# 73       40.25       23.50        8.75        4.25       13.50      16.25
#
#     lagged_2P_PCT  Year  Month_Sin  Month_Cos   Day_Sin   Day_Cos
# 77       0.496177  2014       -0.5   0.866025  0.998717 -0.050649
# 76       0.481492  2014       -0.5   0.866025  0.897805 -0.440394
# 75       0.435226  2014       -0.5   0.866025  0.651372 -0.758758
# 74       0.457214  2014       -0.5   0.866025  0.299363 -0.954139
# 73       0.497108  2014       -0.5   0.866025  0.101168 -0.994869

# %%
df.to_csv('hybrid_paper_NBA_10_seasons.csv', index=False)

# %%
from sklearn.model_selection import train_test_split

y = df[['PTS', 'WL']]
x = df.drop(['PTS', 'WL', '2PA', '2PM', '2P_PCT'], axis=1)
X_trainC, X_validC, y_trainC, y_validC = train_test_split(x, y['WL'], random_state=42)
X_trainR, X_validR, y_trainR, y_validR = train_test_split(x, y['PTS'], random_state=42)
x.head()
# Out:
#        AVG_MIN    AVG_FGM    AVG_FGA  AVG_FG_PCT   AVG_FG3M   AVG_FG3A  \
# 77  252.500000  39.000000  83.500000    0.470500  10.250000  25.000000
# 76  250.000000  37.800000  83.000000    0.457800  10.000000  24.400000
# 75  248.333333  36.000000  81.000000    0.444833  10.000000  24.833333
# 74  247.142857  36.428571  80.285714    0.454571   9.857143  24.142857
# 73  246.250000  37.125000  79.625000    0.467750  10.000000  24.625000
#
#     AVG_FG3_PCT    AVG_FTM    AVG_FTA  AVG_FT_PCT  AVG_OREB   AVG_DREB  \
# 77     0.413750  15.500000  21.750000    0.695750  7.500000  31.000000
# 76     0.412800  18.000000  24.600000    0.712200  8.400000  30.600000
# 75     0.405667  19.500000  25.166667    0.754167  8.500000  30.333333
# 74     0.412000  18.571429  24.142857    0.749571  9.142857  30.714286
# 73     0.409625  18.625000  24.000000    0.759125  8.375000  31.000000
#
#       AVG_REB    AVG_AST   AVG_STL   AVG_BLK    AVG_TOV  AVG_PF     AVG_PTS  \
# 77  38.500000  26.500000  9.500000  5.500000  15.250000  25.500  103.750000
# 76  39.000000  24.800000  9.600000  5.400000  13.800000  23.800  103.600000
# 75  38.833333  24.000000  9.166667  5.000000  14.000000  22.500  101.500000
# 74  39.857143  23.857143  9.000000  4.857143  14.571429  21.000  101.285714
# 73  39.375000  25.000000  9.125000  4.875000  14.375000  20.875  102.875000
#
#     Team  Rival   Home  FGM_lag1  FGM_lag2  FGM_lag3  FGM_lag4  FGA_lag1  \
# 77     0     19   True      43.0      38.0      35.0      40.0      93.0
# 76     0     49  False      33.0      43.0      38.0      35.0      81.0
# 75     0     28   True      27.0      33.0      43.0      38.0      71.0
# 74     0     15   True      39.0      27.0      33.0      43.0      76.0
# 73     0     35  False      42.0      39.0      27.0      33.0      75.0
#
#     FGA_lag2  FGA_lag3  FGA_lag4  FG_PCT_lag1  FG_PCT_lag2  FG_PCT_lag3  \
# 77      92.0      69.0      80.0        0.462        0.413        0.507
# 76      93.0      92.0      69.0        0.407        0.462        0.413
# 75      81.0      93.0      92.0        0.380        0.407        0.462
# 74      71.0      81.0      93.0        0.513        0.380        0.407
# 73      76.0      71.0      81.0        0.560        0.513        0.380
#
#     FG_PCT_lag4  FG3M_lag1  FG3M_lag2  FG3M_lag3  FG3M_lag4  FG3A_lag1  \
# 77        0.500       13.0        8.0        7.0       13.0       33.0
# 76        0.507        9.0       13.0        8.0        7.0       22.0
# 75        0.413       10.0        9.0       13.0        8.0       27.0
# 74        0.462        9.0       10.0        9.0       13.0       20.0
# 73        0.407       11.0        9.0       10.0        9.0       28.0
#
#     FG3A_lag2  FG3A_lag3  FG3A_lag4  FG3_PCT_lag1  FG3_PCT_lag2  FG3_PCT_lag3  \
# 77       25.0       20.0       22.0         0.394         0.320         0.350
# 76       33.0       25.0       20.0         0.409         0.394         0.320
# 75       22.0       33.0       25.0         0.370         0.409         0.394
# 74       27.0       22.0       33.0         0.450         0.370         0.409
# 73       20.0       27.0       22.0         0.393         0.450         0.370
#
#     FG3_PCT_lag4  FT_PCT_lag1  FT_PCT_lag2  FT_PCT_lag3  FT_PCT_lag4  \
# 77         0.591        0.769        0.727        0.758        0.529
# 76         0.350        0.778        0.769        0.727        0.758
# 75         0.320        0.964        0.778        0.769        0.727
# 74         0.394        0.722        0.964        0.778        0.769
# 73         0.409        0.826        0.722        0.964        0.778
#
#     FTM_lag1  FTM_lag2  FTM_lag3  FTM_lag4  FTA_lag1  FTA_lag2  FTA_lag3  \
# 77      20.0       8.0      25.0       9.0      26.0      11.0      33.0
# 76      28.0      20.0       8.0      25.0      36.0      26.0      11.0
# 75      27.0      28.0      20.0       8.0      28.0      36.0      26.0
# 74      13.0      27.0      28.0      20.0      18.0      28.0      36.0
# 73      19.0      13.0      27.0      28.0      23.0      18.0      28.0
#
#     FTA_lag4  OREB_lag1  OREB_lag2  OREB_lag3  OREB_lag4  DREB_lag1  \
# 77      17.0        7.0       10.0        3.0       10.0       31.0
# 76      33.0       12.0        7.0       10.0        3.0       29.0
# 75      11.0        9.0       12.0        7.0       10.0       29.0
# 74      26.0       13.0        9.0       12.0        7.0       33.0
# 73      36.0        3.0       13.0        9.0       12.0       33.0
#
#     DREB_lag2  DREB_lag3  DREB_lag4  REB_lag1  REB_lag2  REB_lag3  REB_lag4  \
# 77       27.0       34.0       32.0      38.0      37.0      37.0      42.0
# 76       31.0       27.0       34.0      41.0      38.0      37.0      37.0
# 75       29.0       31.0       27.0      38.0      41.0      38.0      37.0
# 74       29.0       29.0       31.0      46.0      38.0      41.0      38.0
# 73       33.0       29.0       29.0      36.0      46.0      38.0      41.0
#
#     AST_lag1  AST_lag2  AST_lag3  AST_lag4  STL_lag1  STL_lag2  STL_lag3  \
# 77      28.0      26.0      26.0      26.0       8.0      14.0      10.0
# 76      18.0      28.0      26.0      26.0      10.0       8.0      14.0
# 75      20.0      18.0      28.0      26.0       7.0      10.0       8.0
# 74      23.0      20.0      18.0      28.0       8.0       7.0      10.0
# 73      33.0      23.0      20.0      18.0      10.0       8.0       7.0
#
#     STL_lag4  BLK_lag1  BLK_lag2  BLK_lag3  BLK_lag4  TOV_lag1  TOV_lag2  \
# 77       6.0       3.0       5.0       6.0       8.0      19.0      13.0
# 76      10.0       5.0       3.0       5.0       6.0       8.0      19.0
# 75      14.0       3.0       5.0       3.0       5.0      15.0       8.0
# 74       8.0       4.0       3.0       5.0       3.0      18.0      15.0
# 73      10.0       5.0       4.0       3.0       5.0      13.0      18.0
#
#     TOV_lag3  TOV_lag4  PF_lag1  PF_lag2  PF_lag3  PF_lag4  2P_PCT_lag1  \
# 77      12.0      17.0     33.0     25.0     20.0     24.0     0.500000
# 76      13.0      12.0     17.0     33.0     25.0     20.0     0.406780
# 75      19.0      13.0     16.0     17.0     33.0     25.0     0.386364
# 74       8.0      19.0     12.0     16.0     17.0     33.0     0.535714
# 73      15.0       8.0     20.0     12.0     16.0     17.0     0.659574
#
#     2P_PCT_lag2  2P_PCT_lag3  2P_PCT_lag4  lagged_FGM  lagged_FGA  \
# 77     0.447761     0.571429     0.465517       39.00       83.50
# 76     0.500000     0.447761     0.571429       37.25       83.75
# 75     0.406780     0.500000     0.447761       35.25       84.25
# 74     0.386364     0.406780     0.500000       35.50       80.25
# 73     0.535714     0.386364     0.406780       35.25       75.75
#
#     lagged_FG_PCT  lagged_FG3M  lagged_FG3A  lagged_FG3_PCT  lagged_FT_PCT  \
# 77        0.47050        10.25        25.00         0.41375        0.69575
# 76        0.44725         9.25        25.00         0.36825        0.75800
# 75        0.41550        10.00        26.75         0.37325        0.80950
# 74        0.44050        10.25        25.50         0.40575        0.80825
# 73        0.46500         9.75        24.25         0.40550        0.82250
#
#     lagged_FTM  lagged_FTA  lagged_OREB  lagged_DREB  lagged_REB  lagged_AST  \
# 77       15.50       21.75         7.50        31.00       38.50       26.50
# 76       20.25       26.50         8.00        30.25       38.25       24.50
# 75       20.75       25.25         9.50        29.00       38.50       23.00
# 74       22.00       27.00        10.25        30.50       40.75       22.25
# 73       21.75       26.25         9.25        31.00       40.25       23.50
#
#     lagged_STL  lagged_BLK  lagged_TOV  lagged_PF  lagged_2P_PCT  Year  \
# 77        9.50        5.50       15.25      25.50       0.496177  2014
# 76       10.50        4.75       13.00      23.75       0.481492  2014
# 75        9.75        4.00       13.75      22.75       0.435226  2014
# 74        8.25        3.75       15.00      19.50       0.457214  2014
# 73        8.75        4.25       13.50      16.25       0.497108  2014
#
#     Month_Sin  Month_Cos   Day_Sin   Day_Cos
# 77       -0.5   0.866025  0.998717 -0.050649
# 76       -0.5   0.866025  0.897805 -0.440394
# 75       -0.5   0.866025  0.651372 -0.758758
# 74       -0.5   0.866025  0.299363 -0.954139
# 73       -0.5   0.866025  0.101168 -0.994869

# %%
from xgboost import XGBClassifier as c, XGBRegressor as r

xC = c()
xC.fit(X_trainC, y_trainC)
xR = r()
xR.fit(X_trainR, y_trainR)
xRp = xR.predict(X_validR)
xCp = xC.predict(X_validC)

# %%
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier

tR = DecisionTreeRegressor(min_samples_leaf=25, random_state=42)
tR.fit(X_trainR, y_trainR)
tC = DecisionTreeClassifier(min_samples_leaf=25, random_state=42)
tC.fit(X_trainC, y_trainC)
tRp = tR.predict(X_validR)
tCp = tC.predict(X_validC)

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

def rf(xs, y, callback, n_estimators=40, max_samples=18085,
       max_features=0.5, min_samples_leaf=25, **kwargs):
    return callback(n_jobs=-1, n_estimators=n_estimators,
        max_samples=max_samples, max_features=max_features,
        min_samples_leaf=min_samples_leaf, oob_score=True).fit(xs, y)

rR = rf(X_trainR, y_trainR, RandomForestRegressor)
rC = rf(X_trainC, y_trainC, RandomForestClassifier)
rRp = rR.predict(X_validR)
rCp = rC.predict(X_validC)

# %%
len(y_validR), len(y_validC), len(xRp), len(xCp), len(tRp), len(tCp), len(rRp), len(rCp)
# Out:
# (6029, 6029, 6029, 6029, 6029, 6029, 6029, 6029)

# %%
tR.get_n_leaves(), tC.get_n_leaves()
# Out:
# (559, 552)

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import accuracy_score as acc

acc(y_validC, xCp), acc(y_validC, tCp), acc(y_validC, rCp), mape(y_validR, xRp), mape(y_validR, tRp), mape(y_validR, rRp)
# Out:
# (0.5737269862332062,
#  0.5375684193066843,
#  0.5981091391607232,
#  0.09091293762859207,
#  0.09781112649611859,
#  0.08763936306603791)
